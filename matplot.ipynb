# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1,2])
ypoints = np.array([5,10])
plt.plot(xpoints , ypoints)
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints , ypoints)
plt.show()

# %%
xpoints = np.array([1,6])
ypoints = np.array([4,5])
plt.plot(xpoints , ypoints ,'X')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints , '*''r')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([5,6,7,9])
plt.plot(xpoints,ypoints ,marker='*',ms=30,color='red')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
xpoints = np.array([5,6,7,9])
plt.plot(xpoints,ypoints ,marker='*',ms=30,mec='r',color='black')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints ,marker='o',ms=10,mec='r',color='black')
plt.show()

# %%
ypoints = np.array ([3,8,1,10])
plt.plot(ypoints,marker='*',ms=20,mfc='g',mec='k')
plt.show()

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,marker='*',ms=30,mec='y',mfc='k')
plt.show()

# %%
ypoints = np.array ([3,8,1,10])
plt.plot(ypoints , linestyle='dashed',marker='o',mec='black',mfc='white',ms=20,linewidth=3)
plt.show()

# %%
plt.plot (ypoints , linestyle='dotted',marker='o',ms=25,mfc='g',mec='r')
plt.show()

# %%
xpoints = np.array ([10,20,30])
ypoints = np.array ([1,2,6])
plt.plot(xpoints,ypoints,marker='*',ms=20,color='r',mfc='g',mec='r',linestyle='dashed')

# %%
### you can use keyword argument linewidth or shorter LW to change width of line 
### value is floating numbers in points

ypoints = np.array([3,8,1,10])
plt.plot(ypoints , linewidth=5)

plt.show()

# %%
y1= np.array ([3,8,1,10])
y2= np.array([6,2,5,7])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color='r',linewidth=1)
plt.xlabel('Average Pulse',fontsize=20,color='r')
plt.ylabel('Calorie Burnage',fontsize=20,color='r')
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y,color='r',linewidth=1)
plt.title('Sports Watch Data',fontsize=20,color='g')
plt.xlabel('Average Pulse',fontsize=20,color='r')
plt.ylabel('Calorie Burnage',fontsize=20,color='r')
plt.grid(color='g')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,10,15,20,25])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([23,12,45,23,86,103,87,94,78,77,85,86,12])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# %%
# day 2
x=([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,90,99,90,95,94,100,79,112,91,80,85,90,94])
plt.scatter(x,y)
plt.show()

# %%
#bar
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y,color='black')
plt.show()

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y,color='green')
plt.show()

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y,width=0.2)
plt.show()

# %%
x=np.random.normal(15,5,1000)
plt.hist(x)
# Out:
# (array([ 14.,  38., 109., 172., 237., 228., 136.,  57.,   7.,   2.]),
#  array([ 0.77854119,  3.84799065,  6.9174401 ,  9.98688956, 13.05633902,
#         16.12578848, 19.19523794, 22.2646874 , 25.33413686, 28.40358632,
#         31.47303578]),
#  <a list of 10 Patch objects>)

# %%
x=np.random.normal(100,5,2500)
plt.hist(x)
plt.show()

# %%
y=np.array([10,135,25,15,19])
plt.pie(y)
plt.show()

# %%
y=np.array([10,25,15,10])
mylabels=['cheries','Apples','Bananas','Dates']
plt.pie(y,labels=mylabels)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=['cheries','Apples','Bananas','Dates']
plt.pie(y,labels=mylabels,startangle=180)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=['cheries','Apples','Bananas','Dates']
myexplode=[0,0.95,0.8,0.2]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
y=np.array([25,25,25,100])
mylabels=['cheries','Apples','Bananas','Dates']
mycolors=['black','pink','b','yellow']
plt.pie(y,labels=mylabels,colors=mycolors)
plt.show()

# %%
y=np.array([35,25,25,15])
plt.pie(y)
plt.legend(labels=mylabels)
plt.show()
